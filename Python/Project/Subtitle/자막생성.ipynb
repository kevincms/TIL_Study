# %%
# `pip install assemblyai` (Windows)

import assemblyai as aai

aai.settings.api_key = "4617171ba9e2407d9dbfa1004e9b0ec0"
transcriber = aai.Transcriber()

# transcript = transcriber.transcribe("https://assembly.ai/news.mp4")
transcript = transcriber.transcribe("./test.mp3")

print(transcript.export_subtitles_srt())
# Out:
# 1
# 00:00:00,240 --> 00:00:03,048
# One way to think about the function E to the T is to ask,
#
# 2
# 00:00:03,104 --> 00:00:06,456
# what properties does it have? Probably the most important one.
#
# 3
# 00:00:06,528 --> 00:00:10,200
# And from some points of view, the defining property is that it is its own
#
# 4
# 00:00:10,240 --> 00:00:14,536
# derivative, together with the added condition that inputting 0 returns 1.
#
# 5
# 00:00:14,608 --> 00:00:18,392
# It's actually the only function with this property. And you can illustrate what this
#
# 6
# 00:00:18,416 --> 00:00:22,072
# means with a physical model. If E circumflex T describes your position on
#
# 7
# 00:00:22,096 --> 00:00:25,192
# a number line as a function of time, then you start at the
#
# 8
# 00:00:25,216 --> 00:00:28,868
# number one. And what this equation is saying is that your velocity,
#
# 9
# 00:00:28,964 --> 00:00:33,044
# the derivative of position, is always equal to that position.
#
# 10
# 00:00:33,212 --> 00:00:36,324
# The farther away from zero you are, the faster you move.
#
# 11
# 00:00:36,492 --> 00:00:39,620
# So even before knowing how to compute E circumflex t exactly
#
# 12
# 00:00:39,700 --> 00:00:43,684
# going from a specific time to a specific position, this ability to associate
#
# 13
# 00:00:43,732 --> 00:00:47,124
# each position with a velocity paints a very strong intuitive
#
# 14
# 00:00:47,172 --> 00:00:50,212
# picture of how the function must grow. You know that you'll be
#
# 15
# 00:00:50,236 --> 00:00:53,962
# accelerating and at an accelerating rate, with an all around feeling of
#
# 16
# 00:00:53,986 --> 00:00:55,710
# things getting out of hand quickly.
#
# 17
# 00:00:59,250 --> 00:01:02,858
# And if you add a constant to that exponent, like e to the 2
#
# 18
# 00:01:02,914 --> 00:01:07,498
# times t, the chain rule tells us that the derivative is now two times itself.
#
# 19
# 00:01:07,674 --> 00:01:10,874
# So at every point on the number line, rather than attaching a vector
#
# 20
# 00:01:10,922 --> 00:01:14,538
# corresponding to the number itself, first double the magnitude
#
# 21
# 00:01:14,554 --> 00:01:17,930
# of the position, then attach it. Moving so that your
#
# 22
# 00:01:17,970 --> 00:01:21,242
# position is always e to the 2t is the same thing
#
# 23
# 00:01:21,266 --> 00:01:25,274
# as moving in such a way that your velocity is always twice your position.
#
# 24
# 00:01:25,442 --> 00:01:28,666
# The implication of that too is that our runaway growth feels
#
# 25
# 00:01:28,698 --> 00:01:32,330
# all the more out of control. If that
#
# 26
# 00:01:32,370 --> 00:01:36,122
# constant was negative, say negative 0.5, then your
#
# 27
# 00:01:36,146 --> 00:01:39,386
# velocity vector is always minus 0.5 times your position
#
# 28
# 00:01:39,458 --> 00:01:42,890
# vector, meaning you flip it around 180 degrees and
#
# 29
# 00:01:42,930 --> 00:01:46,442
# scale its length by a half. Moving in such a way that your
#
# 30
# 00:01:46,466 --> 00:01:49,866
# velocity always matches this flipped and squished copy of your position
#
# 31
# 00:01:49,938 --> 00:01:53,836
# vector, you'd go the other direction, slowing down in an exponential decay
#
# 32
# 00:01:53,868 --> 00:01:54,840
# toward zero.
#
# 33
# 00:01:57,380 --> 00:02:01,148
# But what about if that constant was I, the square root of minus 1?
#
# 34
# 00:02:01,284 --> 00:02:04,780
# If your position was always e to the I T, how would you move
#
# 35
# 00:02:04,820 --> 00:02:08,236
# as the time t ticks forward? Well, now the derivative
#
# 36
# 00:02:08,268 --> 00:02:12,060
# of your position will always be I times itself. And multiplying by
#
# 37
# 00:02:12,100 --> 00:02:15,068
# I has the effect of rotating numbers 90 degrees.
#
# 38
# 00:02:15,244 --> 00:02:18,604
# So, as you might expect, things only make sense here if we start thinking beyond
#
# 39
# 00:02:18,652 --> 00:02:22,188
# the number line and in the complex plane. So even
#
# 40
# 00:02:22,244 --> 00:02:25,500
# before you know how to compute E to the I times T, you know
#
# 41
# 00:02:25,540 --> 00:02:28,732
# that for any position this might give for some value of time,
#
# 42
# 00:02:28,836 --> 00:02:32,252
# the velocity at that time will be a 90 degree rotation
#
# 43
# 00:02:32,316 --> 00:02:35,532
# of that position, drawing this for all possible
#
# 44
# 00:02:35,636 --> 00:02:38,460
# positions you might come across, you get a vector field,
#
# 45
# 00:02:38,580 --> 00:02:42,508
# where, as usual with vector fields, you shrink things down to avoid clutter.
#
# 46
# 00:02:42,684 --> 00:02:46,636
# At time t0e^ it will be one. That's our initial
#
# 47
# 00:02:46,668 --> 00:02:49,924
# condition. And there's only one trajectory starting from that position
#
# 48
# 00:02:50,012 --> 00:02:53,908
# where your velocity is always matching the vector that it's passing through a 90
#
# 49
# 00:02:53,964 --> 00:02:57,972
# degree rotation of the position. It's when you go around a circle of radius
#
# 50
# 00:02:58,036 --> 00:03:00,560
# 1 at a speed of 1 unit per second.
#
# 51
# 00:03:01,260 --> 00:03:05,204
# So after PI seconds, you've traced a distance of PI around.
#
# 52
# 00:03:05,372 --> 00:03:09,332
# So e to the I times PI should be minus one. After tau
#
# 53
# 00:03:09,396 --> 00:03:12,660
# seconds, you've gone full circle. E to the I
#
# 54
# 00:03:12,700 --> 00:03:16,278
# times tau equals one, and more generally, E to the I
#
# 55
# 00:03:16,334 --> 00:03:19,782
# times t equals a number that's T radians around this
#
# 56
# 00:03:19,806 --> 00:03:22,170
# unit circle in the complex plane.
#
# 57
# 00:03:28,430 --> 00:03:32,614
# Nevertheless, something might still feel immoral about putting an imaginary
#
# 58
# 00:03:32,662 --> 00:03:35,846
# number up in that exponent. And you would be right to question that.
#
# 59
# 00:03:35,918 --> 00:03:39,398
# What we write as e to the T is a bit of a notational disaster,
#
# 60
# 00:03:39,494 --> 00:03:42,970
# giving the number E and the idea of repeated multiplication way
#
# 61
# 00:03:43,010 --> 00:03:46,506
# more emphasis than they deserve. But my time is up, so I'll
#
# 62
# 00:03:46,538 --> 00:03:48,210
# spare you the full rant until the next video.
